# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\kathan\python_codes\7th sem\ML lab\ML-lab\dataset\Mall_Customers_cluster (1).csv")

# %%
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# drop the column named 'CustomerID' (drop defaults to rows, so specify columns)
data = data.drop(columns=["CustomerID"])

# %%
from sklearn.preprocessing import LabelEncoder
en = LabelEncoder()
data['Genre'] = en.fit_transform(data['Genre'])

# %%
data
# Out:
#      Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0        1   19                  15                      39
# 1        1   21                  15                      81
# 2        0   20                  16                       6
# 3        0   23                  16                      77
# 4        0   31                  17                      40
# ..     ...  ...                 ...                     ...
# 195      0   35                 120                      79
# 196      0   45                 126                      28
# 197      1   32                 126                      74
# 198      1   32                 137                      18
# 199      1   30                 137                      83
#
# [200 rows x 4 columns]

# %%
data.isna().sum()
# Out:
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
model = AgglomerativeClustering(n_clusters=3)
y = model.fit_predict(data)

# %%
silhouette_score(data,y)
# Out:
# np.float64(0.3812859576468096)

# %%
model = AgglomerativeClustering(n_clusters=5)
y = model.fit_predict(data)
silhouette_score(data,y)
# Out:
# np.float64(0.43997527212476695)

# %%
model = AgglomerativeClustering(n_clusters=2)
y = model.fit_predict(data)
silhouette_score(data,y)
# Out:
# np.float64(0.29916602844367)

# %%
model = AgglomerativeClustering(n_clusters=7)
y = model.fit_predict(data)
silhouette_score(data,y)
# Out:
# np.float64(0.42593881050851595)

# %%
model = AgglomerativeClustering(n_clusters=6)
y = model.fit_predict(data)
silhouette_score(data,y)
# Out:
# np.float64(0.4428008535928764)

# %%
import scipy.cluster.hierarchy as sch
dendo = sch.dendrogram(sch.linkage(data, method ='ward'))
plt.title("dendogram")
plt.xlabel("no of clusters")
plt.ylabel("ecludian dist")
# Out:
# Text(0, 0.5, 'ecludian dist')
